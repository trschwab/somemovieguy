# %%
import requests
import logging
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO
import lxml


def is_valid_username(username):
    '''
    Checks to see if a username exists with letterboxd
    '''
    url = f"https://letterboxd.com/{username}/"
    r = requests.get(url)
    if r.status_code == 200:
        logging.info("Valid username supplied")
        return True
    logging.info("Invalid username supplied")
    return False


def get_user_diary_info(a_user):
    '''
    returns a DF of a user's diary information

    # TOOD need to be able to handle users that do not exist
    '''
    df_list = []
    # Get diary URL
    diary_url = get_diary(a_user)
    while diary_url:
        r = requests.get(diary_url)
        soup = BeautifulSoup(r.content, features="lxml")


        # Extract the table as a df
        table = soup.find_all('table')
        df_list.append(pd.read_html(StringIO(str(table)), extract_links="all")[0])

        # Find out if there are any subsequent pages
        older_link = soup.find_all("a", text="Older")

        if older_link:
            new_page = older_link[0]['href']
            diary_url = f"{BASE_URL}{new_page}"
        else:
            diary_url = False
    return_df = pd.concat(df_list)

    return_df["film_url"] = return_df[('Film', None)].apply(lambda x: gen_film_url(x))

    return return_df





BASE_URL = "https://letterboxd.com"

def gen_film_url(a_str):
    return f"https://letterboxd.com/film/{a_str[1].split('/')[3]}/"

def get_diary(a_user):
    return f"{BASE_URL}/{a_user}/films/diary/"

def get_watchlist(a_user):
    return f"{BASE_URL}/{a_user}/watchlist/"


def get_user_data(user: str) -> pd.DataFrame:
    '''
    Gets a df of user data ready to be posted to our model
    '''
    user_df = get_user_diary_info(user)

    c_names = ["month", "day", "film", "released", "rating", "like", "rewatch", "review", "edityou", "film_url"]  # , "img_url", "small_img_url"]

    for i in range(len(c_names)):
        user_df.rename(columns={ user_df.columns[i]: c_names[i] }, inplace=True)

    # user_df.to_csv("expected.csv")
    # explode tuple values into new cols:

    user_df[["month", "month_none"]] = pd.DataFrame(user_df['month'].tolist(), index=user_df.index)
    user_df[["day", "day_none"]] = pd.DataFrame(user_df['day'].tolist(), index=user_df.index)
    user_df[["film", "film_link"]] = pd.DataFrame(user_df['film'].tolist(), index=user_df.index)
    user_df[["released", "released_none"]] = pd.DataFrame(user_df['released'].tolist(), index=user_df.index)
    user_df[["rating", "rating_none"]] = pd.DataFrame(user_df['rating'].tolist(), index=user_df.index)
    user_df[["review", "review_link"]] = pd.DataFrame(user_df['review'].tolist(), index=user_df.index)

    # Convert to dict for iterative processing.. TODO fix this
    dict_df = user_df.to_dict('records')

    for count, item in enumerate(dict_df):
        if item["month"] == '':
            item["month"] = dict_df[count-1]["month"]

    dated_df = pd.DataFrame(dict_df)
    dated_df[["month", "year"]] = dated_df['month'].str.split(' ', expand=True)

    dated_df["name"] = user

    dated_df = dated_df[[
        "name",
        "day",
        "month",
        "year",
        "film",
        "released",
        "rating",
        "review_link",
        "film_link"]]

    return dated_df

# %%
# %pip install lxml

def get_user_watchlist(a_user):
    '''
    returns a DF of a user's diary information

    # TOOD need to be able to handle users that do not exist
    '''
    df_list = []
    # Get diary URL
    watchlist_url = get_watchlist(a_user)

    # Extract data from each poster
    posters = []
    while watchlist_url:
        r = requests.get(watchlist_url)
        soup = BeautifulSoup(r.content)

        # Find all 'li' elements with the class 'poster-container'
        poster_containers = soup.find_all("li", class_="poster-container")
        for poster in poster_containers:
            div = poster.find("div", class_="film-poster")
            if div:
                film_id = div.get("data-film-id", "")
                film_slug = div.get("data-film-slug", "")
                film_url = div.get("data-target-link", "")
                poster_url = div.get("data-poster-url", "")
                title = div.find("img").get("alt", "")
                
                posters.append({
                    "film_id": film_id,
                    "film_slug": film_slug,
                    "film_url": film_url,
                    "poster_url": poster_url,
                    "title": title,
                })

        # Print extracted data
        # for poster in posters:
            # print(poster)

        # Find out if there are any subsequent pages
        older_link = soup.find_all("a", text="Older")

        if older_link:
            new_page = older_link[0]['href']
            watchlist_url = f"{BASE_URL}{new_page}"
        else:
            watchlist_url = False

    # Convert the list of dictionaries into a pandas DataFrame
    watchlist_df = pd.DataFrame(posters)

    return watchlist_df
    

get_user_watchlist("nrg004")
# Out:
# https://letterboxd.com/nrg004/watchlist/
# {'film_id': '25650', 'film_slug': 'sorcerer', 'film_url': '/film/sorcerer/', 'poster_url': '/film/sorcerer/image-150/', 'title': 'Sorcerer'}
# {'film_id': '51261', 'film_slug': 'all-the-presidents-men', 'film_url': '/film/all-the-presidents-men/', 'poster_url': '/film/all-the-presidents-men/image-150/', 'title': "All the President's Men"}
# {'film_id': '45652', 'film_slug': 'the-last-temptation-of-christ', 'film_url': '/film/the-last-temptation-of-christ/', 'poster_url': '/film/the-last-temptation-of-christ/image-150/', 'title': 'The Last Temptation of Christ'}
# {'film_id': '591053', 'film_slug': 'past-lives', 'film_url': '/film/past-lives/', 'poster_url': '/film/past-lives/image-150/', 'title': 'Past Lives'}
# {'film_id': '438692', 'film_slug': 'the-boy-and-the-heron', 'film_url': '/film/the-boy-and-the-heron/', 'poster_url': '/film/the-boy-and-the-heron/image-150/', 'title': 'The Boy and the Heron'}
# {'film_id': '822093', 'film_slug': 'anatomy-of-a-fall', 'film_url': '/film/anatomy-of-a-fall/', 'poster_url': '/film/anatomy-of-a-fall/image-150/', 'title': 'Anatomy of a Fall'}
# {'film_id': '595029', 'film_slug': 'the-creator-2023', 'film_url': '/film/the-creator-2023/', 'poster_url': '/film/the-creator-2023/image-150/', 'title': 'The Creator'}
# {'film_id': '674137', 'film_slug': 'napoleon-2023', 'film_url': '/film/napoleon-2023/', 'poster_url': '/film/napoleon-2023/image-150/', 'title': 'Napoleon'}
# {'film_id': '715856', 'film_slug': 'beau-is-afraid', 'film_url': '/film/beau-is-afraid/', 'poster_url': '/film/beau-is-afraid/image-150/', 'title': 'Beau Is Afraid'}
# {'film_id': '717654', 'film_slug': 'the-killer-2023', 'film_url': '/film/the-killer-2023/', 'poster_url': '/film/the-killer-2023/image-150/', 'title': 'The Killer'}
# {'film_id': '795897', 'film_slug': 'no-hard-feelings-2023', 'film_url': '/film/no-hard-feelings-2023/', 'poster_url': '/film/no-hard-feelings-2023/image-150/', 'title': 'No Hard Feelings'}
# {'film_id': '530882', 'film_slug': 'john-wick-chapter-4', 'film_url': '/film/john-wick-chapter-4/', 'poster_url': '/film/john-wick-chapter-4/image-150/', 'title': 'John Wick: Chapter 4'}
# {'film_id': '668555', 'film_slug': 'asteroid-city', 'film_url': '/film/asteroid-city/', 'poster_url': '/film/asteroid-city/image-150/', 'title': 'Asteroid City'}
# {'film_id': '784328', 'film_slug': 'oppenheimer-2023', 'film_url': '/film/oppenheimer-2023/', 'poster_url': '/film/oppenheimer-2023/image-150/', 'title': 'Oppenheimer'}
# {'film_id': '398009', 'film_slug': 'killers-of-the-flower-moon', 'film_url': '/film/killers-of-the-flower-moon/', 'poster_url': '/film/killers-of-the-flower-moon/image-150/', 'title': 'Killers of the Flower Moon'}
# {'film_id': '48473', 'film_slug': 'carlitos-way', 'film_url': '/film/carlitos-way/', 'poster_url': '/film/carlitos-way/image-150/', 'title': "Carlito's Way"}
# {'film_id': '34606', 'film_slug': 'linda-linda-linda', 'film_url': '/film/linda-linda-linda/', 'poster_url': '/film/linda-linda-linda/image-150/', 'title': 'Linda Linda Linda'}
# {'film_id': '589093', 'film_slug': 'shiva-baby-2020', 'film_url': '/film/shiva-baby-2020/', 'poster_url': '/film/shiva-baby-2020/image-150/', 'title': 'Shiva Baby'}
# {'film_id': '12475', 'film_slug': 'this-must-be-the-place', 'film_url': '/film/this-must-be-the-place/', 'poster_url': '/film/this-must-be-the-place/image-150/', 'title': 'This Must Be the Place'}
# {'film_id': '734096', 'film_slug': 'tar-2022', 'film_url': '/film/tar-2022/', 'poster_url': '/film/tar-2022/image-150/', 'title': 'TÁR'}
# {'film_id': '48106', 'film_slug': 'cloverfield', 'film_url': '/film/cloverfield/', 'poster_url': '/film/cloverfield/image-150/', 'title': 'Cloverfield'}
# {'film_id': '733032', 'film_slug': 'mr-petrified-forrest', 'film_url': '/film/mr-petrified-forrest/', 'poster_url': '/film/mr-petrified-forrest/image-150/', 'title': 'Mr. Petrified Forrest'}
# {'film_id': '51981', 'film_slug': 'brazil', 'film_url': '/film/brazil/', 'poster_url': '/film/brazil/image-150/', 'title': 'Brazil'}
# {'film_id': '51986', 'film_slug': 'twelve-monkeys', 'film_url': '/film/twelve-monkeys/', 'poster_url': '/film/twelve-monkeys/image-150/', 'title': 'Twelve Monkeys'}
# {'film_id': '31595', 'film_slug': 'kwaidan', 'film_url': '/film/kwaidan/', 'poster_url': '/film/kwaidan/image-150/', 'title': 'Kwaidan'}
# {'film_id': '46908', 'film_slug': 'ichi-the-killer', 'film_url': '/film/ichi-the-killer/', 'poster_url': '/film/ichi-the-killer/image-150/', 'title': 'Ichi the Killer'}
# {'film_id': '45628', 'film_slug': 'audition', 'film_url': '/film/audition/', 'poster_url': '/film/audition/image-150/', 'title': 'Audition'}
# {'film_id': '828615', 'film_slug': 'obi-wan-kenobi-the-patterson-cut', 'film_url': '/film/obi-wan-kenobi-the-patterson-cut/', 'poster_url': '/film/obi-wan-kenobi-the-patterson-cut/image-150/', 'title': 'Obi-Wan Kenobi'}
# https://letterboxd.com/nrg004/watchlist/page/2/
# /var/folders/wm/ylb0jk4d1l7d_l9d7pkd032c0000gn/T/ipykernel_70225/785901997.py:44: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   older_link = soup.find_all("a", text="Older")
# {'film_id': '25650', 'film_slug': 'sorcerer', 'film_url': '/film/sorcerer/', 'poster_url': '/film/sorcerer/image-150/', 'title': 'Sorcerer'}
# {'film_id': '51261', 'film_slug': 'all-the-presidents-men', 'film_url': '/film/all-the-presidents-men/', 'poster_url': '/film/all-the-presidents-men/image-150/', 'title': "All the President's Men"}
# {'film_id': '45652', 'film_slug': 'the-last-temptation-of-christ', 'film_url': '/film/the-last-temptation-of-christ/', 'poster_url': '/film/the-last-temptation-of-christ/image-150/', 'title': 'The Last Temptation of Christ'}
# {'film_id': '591053', 'film_slug': 'past-lives', 'film_url': '/film/past-lives/', 'poster_url': '/film/past-lives/image-150/', 'title': 'Past Lives'}
# {'film_id': '438692', 'film_slug': 'the-boy-and-the-heron', 'film_url': '/film/the-boy-and-the-heron/', 'poster_url': '/film/the-boy-and-the-heron/image-150/', 'title': 'The Boy and the Heron'}
# {'film_id': '822093', 'film_slug': 'anatomy-of-a-fall', 'film_url': '/film/anatomy-of-a-fall/', 'poster_url': '/film/anatomy-of-a-fall/image-150/', 'title': 'Anatomy of a Fall'}
# {'film_id': '595029', 'film_slug': 'the-creator-2023', 'film_url': '/film/the-creator-2023/', 'poster_url': '/film/the-creator-2023/image-150/', 'title': 'The Creator'}
# {'film_id': '674137', 'film_slug': 'napoleon-2023', 'film_url': '/film/napoleon-2023/', 'poster_url': '/film/napoleon-2023/image-150/', 'title': 'Napoleon'}
# {'film_id': '715856', 'film_slug': 'beau-is-afraid', 'film_url': '/film/beau-is-afraid/', 'poster_url': '/film/beau-is-afraid/image-150/', 'title': 'Beau Is Afraid'}
# {'film_id': '717654', 'film_slug': 'the-killer-2023', 'film_url': '/film/the-killer-2023/', 'poster_url': '/film/the-killer-2023/image-150/', 'title': 'The Killer'}
# {'film_id': '795897', 'film_slug': 'no-hard-feelings-2023', 'film_url': '/film/no-hard-feelings-2023/', 'poster_url': '/film/no-hard-feelings-2023/image-150/', 'title': 'No Hard Feelings'}
# {'film_id': '530882', 'film_slug': 'john-wick-chapter-4', 'film_url': '/film/john-wick-chapter-4/', 'poster_url': '/film/john-wick-chapter-4/image-150/', 'title': 'John Wick: Chapter 4'}
# {'film_id': '668555', 'film_slug': 'asteroid-city', 'film_url': '/film/asteroid-city/', 'poster_url': '/film/asteroid-city/image-150/', 'title': 'Asteroid City'}
# {'film_id': '784328', 'film_slug': 'oppenheimer-2023', 'film_url': '/film/oppenheimer-2023/', 'poster_url': '/film/oppenheimer-2023/image-150/', 'title': 'Oppenheimer'}
# {'film_id': '398009', 'film_slug': 'killers-of-the-flower-moon', 'film_url': '/film/killers-of-the-flower-moon/', 'poster_url': '/film/killers-of-the-flower-moon/image-150/', 'title': 'Killers of the Flower Moon'}
# {'film_id': '48473', 'film_slug': 'carlitos-way', 'film_url': '/film/carlitos-way/', 'poster_url': '/film/carlitos-way/image-150/', 'title': "Carlito's Way"}
# {'film_id': '34606', 'film_slug': 'linda-linda-linda', 'film_url': '/film/linda-linda-linda/', 'poster_url': '/film/linda-linda-linda/image-150/', 'title': 'Linda Linda Linda'}
# {'film_id': '589093', 'film_slug': 'shiva-baby-2020', 'film_url': '/film/shiva-baby-2020/', 'poster_url': '/film/shiva-baby-2020/image-150/', 'title': 'Shiva Baby'}
# {'film_id': '12475', 'film_slug': 'this-must-be-the-place', 'film_url': '/film/this-must-be-the-place/', 'poster_url': '/film/this-must-be-the-place/image-150/', 'title': 'This Must Be the Place'}
# {'film_id': '734096', 'film_slug': 'tar-2022', 'film_url': '/film/tar-2022/', 'poster_url': '/film/tar-2022/image-150/', 'title': 'TÁR'}
# {'film_id': '48106', 'film_slug': 'cloverfield', 'film_url': '/film/cloverfield/', 'poster_url': '/film/cloverfield/image-150/', 'title': 'Cloverfield'}
# {'film_id': '733032', 'film_slug': 'mr-petrified-forrest', 'film_url': '/film/mr-petrified-forrest/', 'poster_url': '/film/mr-petrified-forrest/image-150/', 'title': 'Mr. Petrified Forrest'}
# {'film_id': '51981', 'film_slug': 'brazil', 'film_url': '/film/brazil/', 'poster_url': '/film/brazil/image-150/', 'title': 'Brazil'}
# {'film_id': '51986', 'film_slug': 'twelve-monkeys', 'film_url': '/film/twelve-monkeys/', 'poster_url': '/film/twelve-monkeys/image-150/', 'title': 'Twelve Monkeys'}
# {'film_id': '31595', 'film_slug': 'kwaidan', 'film_url': '/film/kwaidan/', 'poster_url': '/film/kwaidan/image-150/', 'title': 'Kwaidan'}
# {'film_id': '46908', 'film_slug': 'ichi-the-killer', 'film_url': '/film/ichi-the-killer/', 'poster_url': '/film/ichi-the-killer/image-150/', 'title': 'Ichi the Killer'}
# {'film_id': '45628', 'film_slug': 'audition', 'film_url': '/film/audition/', 'poster_url': '/film/audition/image-150/', 'title': 'Audition'}
# {'film_id': '828615', 'film_slug': 'obi-wan-kenobi-the-patterson-cut', 'film_url': '/film/obi-wan-kenobi-the-patterson-cut/', 'poster_url': '/film/obi-wan-kenobi-the-patterson-cut/image-150/', 'title': 'Obi-Wan Kenobi'}
# {'film_id': '293465', 'film_slug': 'top-gun-maverick', 'film_url': '/film/top-gun-maverick/', 'poster_url': '/film/top-gun-maverick/image-150/', 'title': 'Top Gun: Maverick'}
# {'film_id': '574385', 'film_slug': 'the-unbearable-weight-of-massive-talent', 'film_url': '/film/the-unbearable-weight-of-massive-talent/', 'poster_url': '/film/the-unbearable-weight-of-massive-talent/image-150/', 'title': 'The Unbearable Weight of Massive Talent'}
# {'film_id': '45160', 'film_slug': 'slap-shot', 'film_url': '/film/slap-shot/', 'poster_url': '/film/slap-shot/image-150/', 'title': 'Slap Shot'}
# {'film_id': '513206', 'film_slug': 'after-yang', 'film_url': '/film/after-yang/', 'poster_url': '/film/after-yang/image-150/', 'title': 'After Yang'}
# {'film_id': '527841', 'film_slug': 'the-power-of-the-dog', 'film_url': '/film/the-power-of-the-dog/', 'poster_url': '/film/the-power-of-the-dog/image-150/', 'title': 'The Power of the Dog'}
# {'film_id': '466291', 'film_slug': 'tick-tick-boom-2021', 'film_url': '/film/tick-tick-boom-2021/', 'poster_url': '/film/tick-tick-boom-2021/image-150/', 'title': 'tick, tick... BOOM!'}
# {'film_id': '679291', 'film_slug': 'drive-my-car', 'film_url': '/film/drive-my-car/', 'poster_url': '/film/drive-my-car/image-150/', 'title': 'Drive My Car'}
# {'film_id': '585258', 'film_slug': 'the-worst-person-in-the-world', 'film_url': '/film/the-worst-person-in-the-world/', 'poster_url': '/film/the-worst-person-in-the-world/image-150/', 'title': 'The Worst Person in the World'}
# {'film_id': '615424', 'film_slug': 'when-you-finish-saving-the-world', 'film_url': '/film/when-you-finish-saving-the-world/', 'poster_url': '/film/when-you-finish-saving-the-world/image-150/', 'title': 'When You Finish Saving the World'}
# {'film_id': '621787', 'film_slug': 'dual-2022', 'film_url': '/film/dual-2022/', 'poster_url': '/film/dual-2022/image-150/', 'title': 'Dual'}
# {'film_id': '10261', 'film_slug': 'the-animatrix', 'film_url': '/film/the-animatrix/', 'poster_url': '/film/the-animatrix/image-150/', 'title': 'The Animatrix'}
# {'film_id': '50703', 'film_slug': 'open-your-eyes', 'film_url': '/film/open-your-eyes/', 'poster_url': '/film/open-your-eyes/image-150/', 'title': 'Open Your Eyes'}
# {'film_id': '551275', 'film_slug': 'the-matrix-resurrections', 'film_url': '/film/the-matrix-resurrections/', 'poster_url': '/film/the-matrix-resurrections/image-150/', 'title': 'The Matrix Resurrections'}
# {'film_id': '524592', 'film_slug': 'nightmare-alley-2021', 'film_url': '/film/nightmare-alley-2021/', 'poster_url': '/film/nightmare-alley-2021/image-150/', 'title': 'Nightmare Alley'}
# {'film_id': '683620', 'film_slug': 'red-rocket-2021', 'film_url': '/film/red-rocket-2021/', 'poster_url': '/film/red-rocket-2021/image-150/', 'title': 'Red Rocket'}
# {'film_id': '570193', 'film_slug': 'house-of-gucci', 'film_url': '/film/house-of-gucci/', 'poster_url': '/film/house-of-gucci/image-150/', 'title': 'House of Gucci'}
# {'film_id': '558806', 'film_slug': 'cmon-cmon', 'film_url': '/film/cmon-cmon/', 'poster_url': '/film/cmon-cmon/image-150/', 'title': "C'mon C'mon"}
# {'film_id': '454016', 'film_slug': 'eternals', 'film_url': '/film/eternals/', 'poster_url': '/film/eternals/image-150/', 'title': 'Eternals'}
# {'film_id': '544380', 'film_slug': 'the-last-duel-2021', 'film_url': '/film/the-last-duel-2021/', 'poster_url': '/film/the-last-duel-2021/image-150/', 'title': 'The Last Duel'}
# {'film_id': '43001', 'film_slug': 'have-dreams-will-travel', 'film_url': '/film/have-dreams-will-travel/', 'poster_url': '/film/have-dreams-will-travel/image-150/', 'title': 'Have Dreams, Will Travel'}
# {'film_id': '357826', 'film_slug': 'annette', 'film_url': '/film/annette/', 'poster_url': '/film/annette/image-150/', 'title': 'Annette'}
# {'film_id': '561763', 'film_slug': 'pig-2021', 'film_url': '/film/pig-2021/', 'poster_url': '/film/pig-2021/image-150/', 'title': 'Pig'}
# {'film_id': '369835', 'film_slug': 'the-suicide-squad', 'film_url': '/film/the-suicide-squad/', 'poster_url': '/film/the-suicide-squad/image-150/', 'title': 'The Suicide Squad'}
# {'film_id': '46304', 'film_slug': 'hunger', 'film_url': '/film/hunger/', 'poster_url': '/film/hunger/image-150/', 'title': 'Hunger'}
# {'film_id': '486509', 'film_slug': 'mainstream-2020', 'film_url': '/film/mainstream-2020/', 'poster_url': '/film/mainstream-2020/image-150/', 'title': 'Mainstream'}
# {'film_id': '47939', 'film_slug': 'in-the-name-of-the-father-1993', 'film_url': '/film/in-the-name-of-the-father-1993/', 'poster_url': '/film/in-the-name-of-the-father-1993/image-150/', 'title': 'In the Name of the Father'}
# {'film_id': '45654', 'film_slug': 'interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem', 'film_url': '/film/interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem/', 'poster_url': '/film/interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem/image-150/', 'title': 'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem'}
# {'film_id': '699586', 'film_slug': 'pretend-its-a-city', 'film_url': '/film/pretend-its-a-city/', 'poster_url': '/film/pretend-its-a-city/image-150/', 'title': "Pretend It's a City"}
# https://letterboxd.com/nrg004/watchlist/page/3/
# {'film_id': '25650', 'film_slug': 'sorcerer', 'film_url': '/film/sorcerer/', 'poster_url': '/film/sorcerer/image-150/', 'title': 'Sorcerer'}
# {'film_id': '51261', 'film_slug': 'all-the-presidents-men', 'film_url': '/film/all-the-presidents-men/', 'poster_url': '/film/all-the-presidents-men/image-150/', 'title': "All the President's Men"}
# {'film_id': '45652', 'film_slug': 'the-last-temptation-of-christ', 'film_url': '/film/the-last-temptation-of-christ/', 'poster_url': '/film/the-last-temptation-of-christ/image-150/', 'title': 'The Last Temptation of Christ'}
# {'film_id': '591053', 'film_slug': 'past-lives', 'film_url': '/film/past-lives/', 'poster_url': '/film/past-lives/image-150/', 'title': 'Past Lives'}
# {'film_id': '438692', 'film_slug': 'the-boy-and-the-heron', 'film_url': '/film/the-boy-and-the-heron/', 'poster_url': '/film/the-boy-and-the-heron/image-150/', 'title': 'The Boy and the Heron'}
# {'film_id': '822093', 'film_slug': 'anatomy-of-a-fall', 'film_url': '/film/anatomy-of-a-fall/', 'poster_url': '/film/anatomy-of-a-fall/image-150/', 'title': 'Anatomy of a Fall'}
# {'film_id': '595029', 'film_slug': 'the-creator-2023', 'film_url': '/film/the-creator-2023/', 'poster_url': '/film/the-creator-2023/image-150/', 'title': 'The Creator'}
# {'film_id': '674137', 'film_slug': 'napoleon-2023', 'film_url': '/film/napoleon-2023/', 'poster_url': '/film/napoleon-2023/image-150/', 'title': 'Napoleon'}
# {'film_id': '715856', 'film_slug': 'beau-is-afraid', 'film_url': '/film/beau-is-afraid/', 'poster_url': '/film/beau-is-afraid/image-150/', 'title': 'Beau Is Afraid'}
# {'film_id': '717654', 'film_slug': 'the-killer-2023', 'film_url': '/film/the-killer-2023/', 'poster_url': '/film/the-killer-2023/image-150/', 'title': 'The Killer'}
# {'film_id': '795897', 'film_slug': 'no-hard-feelings-2023', 'film_url': '/film/no-hard-feelings-2023/', 'poster_url': '/film/no-hard-feelings-2023/image-150/', 'title': 'No Hard Feelings'}
# {'film_id': '530882', 'film_slug': 'john-wick-chapter-4', 'film_url': '/film/john-wick-chapter-4/', 'poster_url': '/film/john-wick-chapter-4/image-150/', 'title': 'John Wick: Chapter 4'}
# {'film_id': '668555', 'film_slug': 'asteroid-city', 'film_url': '/film/asteroid-city/', 'poster_url': '/film/asteroid-city/image-150/', 'title': 'Asteroid City'}
# {'film_id': '784328', 'film_slug': 'oppenheimer-2023', 'film_url': '/film/oppenheimer-2023/', 'poster_url': '/film/oppenheimer-2023/image-150/', 'title': 'Oppenheimer'}
# {'film_id': '398009', 'film_slug': 'killers-of-the-flower-moon', 'film_url': '/film/killers-of-the-flower-moon/', 'poster_url': '/film/killers-of-the-flower-moon/image-150/', 'title': 'Killers of the Flower Moon'}
# {'film_id': '48473', 'film_slug': 'carlitos-way', 'film_url': '/film/carlitos-way/', 'poster_url': '/film/carlitos-way/image-150/', 'title': "Carlito's Way"}
# {'film_id': '34606', 'film_slug': 'linda-linda-linda', 'film_url': '/film/linda-linda-linda/', 'poster_url': '/film/linda-linda-linda/image-150/', 'title': 'Linda Linda Linda'}
# {'film_id': '589093', 'film_slug': 'shiva-baby-2020', 'film_url': '/film/shiva-baby-2020/', 'poster_url': '/film/shiva-baby-2020/image-150/', 'title': 'Shiva Baby'}
# {'film_id': '12475', 'film_slug': 'this-must-be-the-place', 'film_url': '/film/this-must-be-the-place/', 'poster_url': '/film/this-must-be-the-place/image-150/', 'title': 'This Must Be the Place'}
# {'film_id': '734096', 'film_slug': 'tar-2022', 'film_url': '/film/tar-2022/', 'poster_url': '/film/tar-2022/image-150/', 'title': 'TÁR'}
# {'film_id': '48106', 'film_slug': 'cloverfield', 'film_url': '/film/cloverfield/', 'poster_url': '/film/cloverfield/image-150/', 'title': 'Cloverfield'}
# {'film_id': '733032', 'film_slug': 'mr-petrified-forrest', 'film_url': '/film/mr-petrified-forrest/', 'poster_url': '/film/mr-petrified-forrest/image-150/', 'title': 'Mr. Petrified Forrest'}
# {'film_id': '51981', 'film_slug': 'brazil', 'film_url': '/film/brazil/', 'poster_url': '/film/brazil/image-150/', 'title': 'Brazil'}
# {'film_id': '51986', 'film_slug': 'twelve-monkeys', 'film_url': '/film/twelve-monkeys/', 'poster_url': '/film/twelve-monkeys/image-150/', 'title': 'Twelve Monkeys'}
# {'film_id': '31595', 'film_slug': 'kwaidan', 'film_url': '/film/kwaidan/', 'poster_url': '/film/kwaidan/image-150/', 'title': 'Kwaidan'}
# {'film_id': '46908', 'film_slug': 'ichi-the-killer', 'film_url': '/film/ichi-the-killer/', 'poster_url': '/film/ichi-the-killer/image-150/', 'title': 'Ichi the Killer'}
# {'film_id': '45628', 'film_slug': 'audition', 'film_url': '/film/audition/', 'poster_url': '/film/audition/image-150/', 'title': 'Audition'}
# {'film_id': '828615', 'film_slug': 'obi-wan-kenobi-the-patterson-cut', 'film_url': '/film/obi-wan-kenobi-the-patterson-cut/', 'poster_url': '/film/obi-wan-kenobi-the-patterson-cut/image-150/', 'title': 'Obi-Wan Kenobi'}
# {'film_id': '293465', 'film_slug': 'top-gun-maverick', 'film_url': '/film/top-gun-maverick/', 'poster_url': '/film/top-gun-maverick/image-150/', 'title': 'Top Gun: Maverick'}
# {'film_id': '574385', 'film_slug': 'the-unbearable-weight-of-massive-talent', 'film_url': '/film/the-unbearable-weight-of-massive-talent/', 'poster_url': '/film/the-unbearable-weight-of-massive-talent/image-150/', 'title': 'The Unbearable Weight of Massive Talent'}
# {'film_id': '45160', 'film_slug': 'slap-shot', 'film_url': '/film/slap-shot/', 'poster_url': '/film/slap-shot/image-150/', 'title': 'Slap Shot'}
# {'film_id': '513206', 'film_slug': 'after-yang', 'film_url': '/film/after-yang/', 'poster_url': '/film/after-yang/image-150/', 'title': 'After Yang'}
# {'film_id': '527841', 'film_slug': 'the-power-of-the-dog', 'film_url': '/film/the-power-of-the-dog/', 'poster_url': '/film/the-power-of-the-dog/image-150/', 'title': 'The Power of the Dog'}
# {'film_id': '466291', 'film_slug': 'tick-tick-boom-2021', 'film_url': '/film/tick-tick-boom-2021/', 'poster_url': '/film/tick-tick-boom-2021/image-150/', 'title': 'tick, tick... BOOM!'}
# {'film_id': '679291', 'film_slug': 'drive-my-car', 'film_url': '/film/drive-my-car/', 'poster_url': '/film/drive-my-car/image-150/', 'title': 'Drive My Car'}
# {'film_id': '585258', 'film_slug': 'the-worst-person-in-the-world', 'film_url': '/film/the-worst-person-in-the-world/', 'poster_url': '/film/the-worst-person-in-the-world/image-150/', 'title': 'The Worst Person in the World'}
# {'film_id': '615424', 'film_slug': 'when-you-finish-saving-the-world', 'film_url': '/film/when-you-finish-saving-the-world/', 'poster_url': '/film/when-you-finish-saving-the-world/image-150/', 'title': 'When You Finish Saving the World'}
# {'film_id': '621787', 'film_slug': 'dual-2022', 'film_url': '/film/dual-2022/', 'poster_url': '/film/dual-2022/image-150/', 'title': 'Dual'}
# {'film_id': '10261', 'film_slug': 'the-animatrix', 'film_url': '/film/the-animatrix/', 'poster_url': '/film/the-animatrix/image-150/', 'title': 'The Animatrix'}
# {'film_id': '50703', 'film_slug': 'open-your-eyes', 'film_url': '/film/open-your-eyes/', 'poster_url': '/film/open-your-eyes/image-150/', 'title': 'Open Your Eyes'}
# {'film_id': '551275', 'film_slug': 'the-matrix-resurrections', 'film_url': '/film/the-matrix-resurrections/', 'poster_url': '/film/the-matrix-resurrections/image-150/', 'title': 'The Matrix Resurrections'}
# {'film_id': '524592', 'film_slug': 'nightmare-alley-2021', 'film_url': '/film/nightmare-alley-2021/', 'poster_url': '/film/nightmare-alley-2021/image-150/', 'title': 'Nightmare Alley'}
# {'film_id': '683620', 'film_slug': 'red-rocket-2021', 'film_url': '/film/red-rocket-2021/', 'poster_url': '/film/red-rocket-2021/image-150/', 'title': 'Red Rocket'}
# {'film_id': '570193', 'film_slug': 'house-of-gucci', 'film_url': '/film/house-of-gucci/', 'poster_url': '/film/house-of-gucci/image-150/', 'title': 'House of Gucci'}
# {'film_id': '558806', 'film_slug': 'cmon-cmon', 'film_url': '/film/cmon-cmon/', 'poster_url': '/film/cmon-cmon/image-150/', 'title': "C'mon C'mon"}
# {'film_id': '454016', 'film_slug': 'eternals', 'film_url': '/film/eternals/', 'poster_url': '/film/eternals/image-150/', 'title': 'Eternals'}
# {'film_id': '544380', 'film_slug': 'the-last-duel-2021', 'film_url': '/film/the-last-duel-2021/', 'poster_url': '/film/the-last-duel-2021/image-150/', 'title': 'The Last Duel'}
# {'film_id': '43001', 'film_slug': 'have-dreams-will-travel', 'film_url': '/film/have-dreams-will-travel/', 'poster_url': '/film/have-dreams-will-travel/image-150/', 'title': 'Have Dreams, Will Travel'}
# {'film_id': '357826', 'film_slug': 'annette', 'film_url': '/film/annette/', 'poster_url': '/film/annette/image-150/', 'title': 'Annette'}
# {'film_id': '561763', 'film_slug': 'pig-2021', 'film_url': '/film/pig-2021/', 'poster_url': '/film/pig-2021/image-150/', 'title': 'Pig'}
# {'film_id': '369835', 'film_slug': 'the-suicide-squad', 'film_url': '/film/the-suicide-squad/', 'poster_url': '/film/the-suicide-squad/image-150/', 'title': 'The Suicide Squad'}
# {'film_id': '46304', 'film_slug': 'hunger', 'film_url': '/film/hunger/', 'poster_url': '/film/hunger/image-150/', 'title': 'Hunger'}
# {'film_id': '486509', 'film_slug': 'mainstream-2020', 'film_url': '/film/mainstream-2020/', 'poster_url': '/film/mainstream-2020/image-150/', 'title': 'Mainstream'}
# {'film_id': '47939', 'film_slug': 'in-the-name-of-the-father-1993', 'film_url': '/film/in-the-name-of-the-father-1993/', 'poster_url': '/film/in-the-name-of-the-father-1993/image-150/', 'title': 'In the Name of the Father'}
# {'film_id': '45654', 'film_slug': 'interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem', 'film_url': '/film/interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem/', 'poster_url': '/film/interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem/image-150/', 'title': 'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem'}
# {'film_id': '699586', 'film_slug': 'pretend-its-a-city', 'film_url': '/film/pretend-its-a-city/', 'poster_url': '/film/pretend-its-a-city/image-150/', 'title': "Pretend It's a City"}
# {'film_id': '46175', 'film_slug': 'perfect-blue', 'film_url': '/film/perfect-blue/', 'poster_url': '/film/perfect-blue/image-150/', 'title': 'Perfect Blue'}
# {'film_id': '137768', 'film_slug': 'revolution-1968', 'film_url': '/film/revolution-1968/', 'poster_url': '/film/revolution-1968/image-150/', 'title': 'Revolution'}
# {'film_id': '267192', 'film_slug': 'greenwich-village-story', 'film_url': '/film/greenwich-village-story/', 'poster_url': '/film/greenwich-village-story/image-150/', 'title': 'Greenwich Village Story'}
# {'film_id': '333310', 'film_slug': 'the-killing-of-a-sacred-deer', 'film_url': '/film/the-killing-of-a-sacred-deer/', 'poster_url': '/film/the-killing-of-a-sacred-deer/image-150/', 'title': 'The Killing of a Sacred Deer'}
# {'film_id': '17623', 'film_slug': 'simple-men', 'film_url': '/film/simple-men/', 'poster_url': '/film/simple-men/image-150/', 'title': 'Simple Men'}
# {'film_id': '30693', 'film_slug': 'the-black-windmill', 'film_url': '/film/the-black-windmill/', 'poster_url': '/film/the-black-windmill/image-150/', 'title': 'The Black Windmill'}
# {'film_id': '47096', 'film_slug': 'glengarry-glen-ross', 'film_url': '/film/glengarry-glen-ross/', 'poster_url': '/film/glengarry-glen-ross/image-150/', 'title': 'Glengarry Glen Ross'}
# {'film_id': '146770', 'film_slug': 'philomena', 'film_url': '/film/philomena/', 'poster_url': '/film/philomena/image-150/', 'title': 'Philomena'}
# {'film_id': '586944', 'film_slug': 'one-night-in-miami', 'film_url': '/film/one-night-in-miami/', 'poster_url': '/film/one-night-in-miami/image-150/', 'title': 'One Night in Miami...'}
# {'film_id': '2537', 'film_slug': 'the-trip-2010', 'film_url': '/film/the-trip-2010/', 'poster_url': '/film/the-trip-2010/image-150/', 'title': 'The Trip'}
# {'film_id': '33714', 'film_slug': 'kicking-and-screaming', 'film_url': '/film/kicking-and-screaming/', 'poster_url': '/film/kicking-and-screaming/image-150/', 'title': 'Kicking and Screaming'}
# {'film_id': '96083', 'film_slug': 'frances-ha', 'film_url': '/film/frances-ha/', 'poster_url': '/film/frances-ha/image-150/', 'title': 'Frances Ha'}
# {'film_id': '330739', 'film_slug': 'the-meyerowitz-stories-new-and-selected', 'film_url': '/film/the-meyerowitz-stories-new-and-selected/', 'poster_url': '/film/the-meyerowitz-stories-new-and-selected/image-150/', 'title': 'The Meyerowitz Stories (New and Selected)'}
# {'film_id': '50112', 'film_slug': 'adaptation', 'film_url': '/film/adaptation/', 'poster_url': '/film/adaptation/image-150/', 'title': 'Adaptation.'}
# {'film_id': '337899', 'film_slug': 'a-hidden-life-2019', 'film_url': '/film/a-hidden-life-2019/', 'poster_url': '/film/a-hidden-life-2019/image-150/', 'title': 'A Hidden Life'}
# {'film_id': '29041', 'film_slug': 'enter-the-void', 'film_url': '/film/enter-the-void/', 'poster_url': '/film/enter-the-void/image-150/', 'title': 'Enter the Void'}
# {'film_id': '48024', 'film_slug': 'the-cook-the-thief-his-wife-her-lover', 'film_url': '/film/the-cook-the-thief-his-wife-her-lover/', 'poster_url': '/film/the-cook-the-thief-his-wife-her-lover/image-150/', 'title': 'The Cook, the Thief, His Wife & Her Lover'}
# {'film_id': '645487', 'film_slug': 'malcolm-marie', 'film_url': '/film/malcolm-marie/', 'poster_url': '/film/malcolm-marie/image-150/', 'title': 'Malcolm & Marie'}
# {'film_id': '49124', 'film_slug': 'ghost-dog-the-way-of-the-samurai', 'film_url': '/film/ghost-dog-the-way-of-the-samurai/', 'poster_url': '/film/ghost-dog-the-way-of-the-samurai/image-150/', 'title': 'Ghost Dog: The Way of the Samurai'}
# {'film_id': '50980', 'film_slug': 'down-by-law', 'film_url': '/film/down-by-law/', 'poster_url': '/film/down-by-law/image-150/', 'title': 'Down by Law'}
# {'film_id': '114563', 'film_slug': 'only-lovers-left-alive', 'film_url': '/film/only-lovers-left-alive/', 'poster_url': '/film/only-lovers-left-alive/image-150/', 'title': 'Only Lovers Left Alive'}
# {'film_id': '306491', 'film_slug': 'paterson', 'film_url': '/film/paterson/', 'poster_url': '/film/paterson/image-150/', 'title': 'Paterson'}
# {'film_id': '51570', 'film_slug': 'rashomon', 'film_url': '/film/rashomon/', 'poster_url': '/film/rashomon/image-150/', 'title': 'Rashomon'}
# {'film_id': '46824', 'film_slug': 'lords-of-dogtown', 'film_url': '/film/lords-of-dogtown/', 'poster_url': '/film/lords-of-dogtown/image-150/', 'title': 'Lords of Dogtown'}
# {'film_id': '51620', 'film_slug': 'the-seventh-seal', 'film_url': '/film/the-seventh-seal/', 'poster_url': '/film/the-seventh-seal/image-150/', 'title': 'The Seventh Seal'}
# {'film_id': '51740', 'film_slug': 'true-romance', 'film_url': '/film/true-romance/', 'poster_url': '/film/true-romance/image-150/', 'title': 'True Romance'}
# {'film_id': '269460', 'film_slug': 'colossal-2016', 'film_url': '/film/colossal-2016/', 'poster_url': '/film/colossal-2016/image-150/', 'title': 'Colossal'}
# {'film_id': '48327', 'film_slug': 'three-kings', 'film_url': '/film/three-kings/', 'poster_url': '/film/three-kings/image-150/', 'title': 'Three Kings'}
# https://letterboxd.com/nrg004/watchlist/page/4/
# {'film_id': '25650', 'film_slug': 'sorcerer', 'film_url': '/film/sorcerer/', 'poster_url': '/film/sorcerer/image-150/', 'title': 'Sorcerer'}
# {'film_id': '51261', 'film_slug': 'all-the-presidents-men', 'film_url': '/film/all-the-presidents-men/', 'poster_url': '/film/all-the-presidents-men/image-150/', 'title': "All the President's Men"}
# {'film_id': '45652', 'film_slug': 'the-last-temptation-of-christ', 'film_url': '/film/the-last-temptation-of-christ/', 'poster_url': '/film/the-last-temptation-of-christ/image-150/', 'title': 'The Last Temptation of Christ'}
# {'film_id': '591053', 'film_slug': 'past-lives', 'film_url': '/film/past-lives/', 'poster_url': '/film/past-lives/image-150/', 'title': 'Past Lives'}
# {'film_id': '438692', 'film_slug': 'the-boy-and-the-heron', 'film_url': '/film/the-boy-and-the-heron/', 'poster_url': '/film/the-boy-and-the-heron/image-150/', 'title': 'The Boy and the Heron'}
# {'film_id': '822093', 'film_slug': 'anatomy-of-a-fall', 'film_url': '/film/anatomy-of-a-fall/', 'poster_url': '/film/anatomy-of-a-fall/image-150/', 'title': 'Anatomy of a Fall'}
# {'film_id': '595029', 'film_slug': 'the-creator-2023', 'film_url': '/film/the-creator-2023/', 'poster_url': '/film/the-creator-2023/image-150/', 'title': 'The Creator'}
# {'film_id': '674137', 'film_slug': 'napoleon-2023', 'film_url': '/film/napoleon-2023/', 'poster_url': '/film/napoleon-2023/image-150/', 'title': 'Napoleon'}
# {'film_id': '715856', 'film_slug': 'beau-is-afraid', 'film_url': '/film/beau-is-afraid/', 'poster_url': '/film/beau-is-afraid/image-150/', 'title': 'Beau Is Afraid'}
# {'film_id': '717654', 'film_slug': 'the-killer-2023', 'film_url': '/film/the-killer-2023/', 'poster_url': '/film/the-killer-2023/image-150/', 'title': 'The Killer'}
# {'film_id': '795897', 'film_slug': 'no-hard-feelings-2023', 'film_url': '/film/no-hard-feelings-2023/', 'poster_url': '/film/no-hard-feelings-2023/image-150/', 'title': 'No Hard Feelings'}
# {'film_id': '530882', 'film_slug': 'john-wick-chapter-4', 'film_url': '/film/john-wick-chapter-4/', 'poster_url': '/film/john-wick-chapter-4/image-150/', 'title': 'John Wick: Chapter 4'}
# {'film_id': '668555', 'film_slug': 'asteroid-city', 'film_url': '/film/asteroid-city/', 'poster_url': '/film/asteroid-city/image-150/', 'title': 'Asteroid City'}
# {'film_id': '784328', 'film_slug': 'oppenheimer-2023', 'film_url': '/film/oppenheimer-2023/', 'poster_url': '/film/oppenheimer-2023/image-150/', 'title': 'Oppenheimer'}
# {'film_id': '398009', 'film_slug': 'killers-of-the-flower-moon', 'film_url': '/film/killers-of-the-flower-moon/', 'poster_url': '/film/killers-of-the-flower-moon/image-150/', 'title': 'Killers of the Flower Moon'}
# {'film_id': '48473', 'film_slug': 'carlitos-way', 'film_url': '/film/carlitos-way/', 'poster_url': '/film/carlitos-way/image-150/', 'title': "Carlito's Way"}
# {'film_id': '34606', 'film_slug': 'linda-linda-linda', 'film_url': '/film/linda-linda-linda/', 'poster_url': '/film/linda-linda-linda/image-150/', 'title': 'Linda Linda Linda'}
# {'film_id': '589093', 'film_slug': 'shiva-baby-2020', 'film_url': '/film/shiva-baby-2020/', 'poster_url': '/film/shiva-baby-2020/image-150/', 'title': 'Shiva Baby'}
# {'film_id': '12475', 'film_slug': 'this-must-be-the-place', 'film_url': '/film/this-must-be-the-place/', 'poster_url': '/film/this-must-be-the-place/image-150/', 'title': 'This Must Be the Place'}
# {'film_id': '734096', 'film_slug': 'tar-2022', 'film_url': '/film/tar-2022/', 'poster_url': '/film/tar-2022/image-150/', 'title': 'TÁR'}
# {'film_id': '48106', 'film_slug': 'cloverfield', 'film_url': '/film/cloverfield/', 'poster_url': '/film/cloverfield/image-150/', 'title': 'Cloverfield'}
# {'film_id': '733032', 'film_slug': 'mr-petrified-forrest', 'film_url': '/film/mr-petrified-forrest/', 'poster_url': '/film/mr-petrified-forrest/image-150/', 'title': 'Mr. Petrified Forrest'}
# {'film_id': '51981', 'film_slug': 'brazil', 'film_url': '/film/brazil/', 'poster_url': '/film/brazil/image-150/', 'title': 'Brazil'}
# {'film_id': '51986', 'film_slug': 'twelve-monkeys', 'film_url': '/film/twelve-monkeys/', 'poster_url': '/film/twelve-monkeys/image-150/', 'title': 'Twelve Monkeys'}
# {'film_id': '31595', 'film_slug': 'kwaidan', 'film_url': '/film/kwaidan/', 'poster_url': '/film/kwaidan/image-150/', 'title': 'Kwaidan'}
# {'film_id': '46908', 'film_slug': 'ichi-the-killer', 'film_url': '/film/ichi-the-killer/', 'poster_url': '/film/ichi-the-killer/image-150/', 'title': 'Ichi the Killer'}
# {'film_id': '45628', 'film_slug': 'audition', 'film_url': '/film/audition/', 'poster_url': '/film/audition/image-150/', 'title': 'Audition'}
# {'film_id': '828615', 'film_slug': 'obi-wan-kenobi-the-patterson-cut', 'film_url': '/film/obi-wan-kenobi-the-patterson-cut/', 'poster_url': '/film/obi-wan-kenobi-the-patterson-cut/image-150/', 'title': 'Obi-Wan Kenobi'}
# {'film_id': '293465', 'film_slug': 'top-gun-maverick', 'film_url': '/film/top-gun-maverick/', 'poster_url': '/film/top-gun-maverick/image-150/', 'title': 'Top Gun: Maverick'}
# {'film_id': '574385', 'film_slug': 'the-unbearable-weight-of-massive-talent', 'film_url': '/film/the-unbearable-weight-of-massive-talent/', 'poster_url': '/film/the-unbearable-weight-of-massive-talent/image-150/', 'title': 'The Unbearable Weight of Massive Talent'}
# {'film_id': '45160', 'film_slug': 'slap-shot', 'film_url': '/film/slap-shot/', 'poster_url': '/film/slap-shot/image-150/', 'title': 'Slap Shot'}
# {'film_id': '513206', 'film_slug': 'after-yang', 'film_url': '/film/after-yang/', 'poster_url': '/film/after-yang/image-150/', 'title': 'After Yang'}
# {'film_id': '527841', 'film_slug': 'the-power-of-the-dog', 'film_url': '/film/the-power-of-the-dog/', 'poster_url': '/film/the-power-of-the-dog/image-150/', 'title': 'The Power of the Dog'}
# {'film_id': '466291', 'film_slug': 'tick-tick-boom-2021', 'film_url': '/film/tick-tick-boom-2021/', 'poster_url': '/film/tick-tick-boom-2021/image-150/', 'title': 'tick, tick... BOOM!'}
# {'film_id': '679291', 'film_slug': 'drive-my-car', 'film_url': '/film/drive-my-car/', 'poster_url': '/film/drive-my-car/image-150/', 'title': 'Drive My Car'}
# {'film_id': '585258', 'film_slug': 'the-worst-person-in-the-world', 'film_url': '/film/the-worst-person-in-the-world/', 'poster_url': '/film/the-worst-person-in-the-world/image-150/', 'title': 'The Worst Person in the World'}
# {'film_id': '615424', 'film_slug': 'when-you-finish-saving-the-world', 'film_url': '/film/when-you-finish-saving-the-world/', 'poster_url': '/film/when-you-finish-saving-the-world/image-150/', 'title': 'When You Finish Saving the World'}
# {'film_id': '621787', 'film_slug': 'dual-2022', 'film_url': '/film/dual-2022/', 'poster_url': '/film/dual-2022/image-150/', 'title': 'Dual'}
# {'film_id': '10261', 'film_slug': 'the-animatrix', 'film_url': '/film/the-animatrix/', 'poster_url': '/film/the-animatrix/image-150/', 'title': 'The Animatrix'}
# {'film_id': '50703', 'film_slug': 'open-your-eyes', 'film_url': '/film/open-your-eyes/', 'poster_url': '/film/open-your-eyes/image-150/', 'title': 'Open Your Eyes'}
# {'film_id': '551275', 'film_slug': 'the-matrix-resurrections', 'film_url': '/film/the-matrix-resurrections/', 'poster_url': '/film/the-matrix-resurrections/image-150/', 'title': 'The Matrix Resurrections'}
# {'film_id': '524592', 'film_slug': 'nightmare-alley-2021', 'film_url': '/film/nightmare-alley-2021/', 'poster_url': '/film/nightmare-alley-2021/image-150/', 'title': 'Nightmare Alley'}
# {'film_id': '683620', 'film_slug': 'red-rocket-2021', 'film_url': '/film/red-rocket-2021/', 'poster_url': '/film/red-rocket-2021/image-150/', 'title': 'Red Rocket'}
# {'film_id': '570193', 'film_slug': 'house-of-gucci', 'film_url': '/film/house-of-gucci/', 'poster_url': '/film/house-of-gucci/image-150/', 'title': 'House of Gucci'}
# {'film_id': '558806', 'film_slug': 'cmon-cmon', 'film_url': '/film/cmon-cmon/', 'poster_url': '/film/cmon-cmon/image-150/', 'title': "C'mon C'mon"}
# {'film_id': '454016', 'film_slug': 'eternals', 'film_url': '/film/eternals/', 'poster_url': '/film/eternals/image-150/', 'title': 'Eternals'}
# {'film_id': '544380', 'film_slug': 'the-last-duel-2021', 'film_url': '/film/the-last-duel-2021/', 'poster_url': '/film/the-last-duel-2021/image-150/', 'title': 'The Last Duel'}
# {'film_id': '43001', 'film_slug': 'have-dreams-will-travel', 'film_url': '/film/have-dreams-will-travel/', 'poster_url': '/film/have-dreams-will-travel/image-150/', 'title': 'Have Dreams, Will Travel'}
# {'film_id': '357826', 'film_slug': 'annette', 'film_url': '/film/annette/', 'poster_url': '/film/annette/image-150/', 'title': 'Annette'}
# {'film_id': '561763', 'film_slug': 'pig-2021', 'film_url': '/film/pig-2021/', 'poster_url': '/film/pig-2021/image-150/', 'title': 'Pig'}
# {'film_id': '369835', 'film_slug': 'the-suicide-squad', 'film_url': '/film/the-suicide-squad/', 'poster_url': '/film/the-suicide-squad/image-150/', 'title': 'The Suicide Squad'}
# {'film_id': '46304', 'film_slug': 'hunger', 'film_url': '/film/hunger/', 'poster_url': '/film/hunger/image-150/', 'title': 'Hunger'}
# {'film_id': '486509', 'film_slug': 'mainstream-2020', 'film_url': '/film/mainstream-2020/', 'poster_url': '/film/mainstream-2020/image-150/', 'title': 'Mainstream'}
# {'film_id': '47939', 'film_slug': 'in-the-name-of-the-father-1993', 'film_url': '/film/in-the-name-of-the-father-1993/', 'poster_url': '/film/in-the-name-of-the-father-1993/image-150/', 'title': 'In the Name of the Father'}
# {'film_id': '45654', 'film_slug': 'interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem', 'film_url': '/film/interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem/', 'poster_url': '/film/interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem/image-150/', 'title': 'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem'}
# {'film_id': '699586', 'film_slug': 'pretend-its-a-city', 'film_url': '/film/pretend-its-a-city/', 'poster_url': '/film/pretend-its-a-city/image-150/', 'title': "Pretend It's a City"}
# {'film_id': '46175', 'film_slug': 'perfect-blue', 'film_url': '/film/perfect-blue/', 'poster_url': '/film/perfect-blue/image-150/', 'title': 'Perfect Blue'}
# {'film_id': '137768', 'film_slug': 'revolution-1968', 'film_url': '/film/revolution-1968/', 'poster_url': '/film/revolution-1968/image-150/', 'title': 'Revolution'}
# {'film_id': '267192', 'film_slug': 'greenwich-village-story', 'film_url': '/film/greenwich-village-story/', 'poster_url': '/film/greenwich-village-story/image-150/', 'title': 'Greenwich Village Story'}
# {'film_id': '333310', 'film_slug': 'the-killing-of-a-sacred-deer', 'film_url': '/film/the-killing-of-a-sacred-deer/', 'poster_url': '/film/the-killing-of-a-sacred-deer/image-150/', 'title': 'The Killing of a Sacred Deer'}
# {'film_id': '17623', 'film_slug': 'simple-men', 'film_url': '/film/simple-men/', 'poster_url': '/film/simple-men/image-150/', 'title': 'Simple Men'}
# {'film_id': '30693', 'film_slug': 'the-black-windmill', 'film_url': '/film/the-black-windmill/', 'poster_url': '/film/the-black-windmill/image-150/', 'title': 'The Black Windmill'}
# {'film_id': '47096', 'film_slug': 'glengarry-glen-ross', 'film_url': '/film/glengarry-glen-ross/', 'poster_url': '/film/glengarry-glen-ross/image-150/', 'title': 'Glengarry Glen Ross'}
# {'film_id': '146770', 'film_slug': 'philomena', 'film_url': '/film/philomena/', 'poster_url': '/film/philomena/image-150/', 'title': 'Philomena'}
# {'film_id': '586944', 'film_slug': 'one-night-in-miami', 'film_url': '/film/one-night-in-miami/', 'poster_url': '/film/one-night-in-miami/image-150/', 'title': 'One Night in Miami...'}
# {'film_id': '2537', 'film_slug': 'the-trip-2010', 'film_url': '/film/the-trip-2010/', 'poster_url': '/film/the-trip-2010/image-150/', 'title': 'The Trip'}
# {'film_id': '33714', 'film_slug': 'kicking-and-screaming', 'film_url': '/film/kicking-and-screaming/', 'poster_url': '/film/kicking-and-screaming/image-150/', 'title': 'Kicking and Screaming'}
# {'film_id': '96083', 'film_slug': 'frances-ha', 'film_url': '/film/frances-ha/', 'poster_url': '/film/frances-ha/image-150/', 'title': 'Frances Ha'}
# {'film_id': '330739', 'film_slug': 'the-meyerowitz-stories-new-and-selected', 'film_url': '/film/the-meyerowitz-stories-new-and-selected/', 'poster_url': '/film/the-meyerowitz-stories-new-and-selected/image-150/', 'title': 'The Meyerowitz Stories (New and Selected)'}
# {'film_id': '50112', 'film_slug': 'adaptation', 'film_url': '/film/adaptation/', 'poster_url': '/film/adaptation/image-150/', 'title': 'Adaptation.'}
# {'film_id': '337899', 'film_slug': 'a-hidden-life-2019', 'film_url': '/film/a-hidden-life-2019/', 'poster_url': '/film/a-hidden-life-2019/image-150/', 'title': 'A Hidden Life'}
# {'film_id': '29041', 'film_slug': 'enter-the-void', 'film_url': '/film/enter-the-void/', 'poster_url': '/film/enter-the-void/image-150/', 'title': 'Enter the Void'}
# {'film_id': '48024', 'film_slug': 'the-cook-the-thief-his-wife-her-lover', 'film_url': '/film/the-cook-the-thief-his-wife-her-lover/', 'poster_url': '/film/the-cook-the-thief-his-wife-her-lover/image-150/', 'title': 'The Cook, the Thief, His Wife & Her Lover'}
# {'film_id': '645487', 'film_slug': 'malcolm-marie', 'film_url': '/film/malcolm-marie/', 'poster_url': '/film/malcolm-marie/image-150/', 'title': 'Malcolm & Marie'}
# {'film_id': '49124', 'film_slug': 'ghost-dog-the-way-of-the-samurai', 'film_url': '/film/ghost-dog-the-way-of-the-samurai/', 'poster_url': '/film/ghost-dog-the-way-of-the-samurai/image-150/', 'title': 'Ghost Dog: The Way of the Samurai'}
# {'film_id': '50980', 'film_slug': 'down-by-law', 'film_url': '/film/down-by-law/', 'poster_url': '/film/down-by-law/image-150/', 'title': 'Down by Law'}
# {'film_id': '114563', 'film_slug': 'only-lovers-left-alive', 'film_url': '/film/only-lovers-left-alive/', 'poster_url': '/film/only-lovers-left-alive/image-150/', 'title': 'Only Lovers Left Alive'}
# {'film_id': '306491', 'film_slug': 'paterson', 'film_url': '/film/paterson/', 'poster_url': '/film/paterson/image-150/', 'title': 'Paterson'}
# {'film_id': '51570', 'film_slug': 'rashomon', 'film_url': '/film/rashomon/', 'poster_url': '/film/rashomon/image-150/', 'title': 'Rashomon'}
# {'film_id': '46824', 'film_slug': 'lords-of-dogtown', 'film_url': '/film/lords-of-dogtown/', 'poster_url': '/film/lords-of-dogtown/image-150/', 'title': 'Lords of Dogtown'}
# {'film_id': '51620', 'film_slug': 'the-seventh-seal', 'film_url': '/film/the-seventh-seal/', 'poster_url': '/film/the-seventh-seal/image-150/', 'title': 'The Seventh Seal'}
# {'film_id': '51740', 'film_slug': 'true-romance', 'film_url': '/film/true-romance/', 'poster_url': '/film/true-romance/image-150/', 'title': 'True Romance'}
# {'film_id': '269460', 'film_slug': 'colossal-2016', 'film_url': '/film/colossal-2016/', 'poster_url': '/film/colossal-2016/image-150/', 'title': 'Colossal'}
# {'film_id': '48327', 'film_slug': 'three-kings', 'film_url': '/film/three-kings/', 'poster_url': '/film/three-kings/image-150/', 'title': 'Three Kings'}
# {'film_id': '27322', 'film_slug': 'falling-down', 'film_url': '/film/falling-down/', 'poster_url': '/film/falling-down/image-150/', 'title': 'Falling Down'}
# {'film_id': '312204', 'film_slug': 'jackie-2016', 'film_url': '/film/jackie-2016/', 'poster_url': '/film/jackie-2016/image-150/', 'title': 'Jackie'}
# {'film_id': '515467', 'film_slug': 'palm-springs-2020', 'film_url': '/film/palm-springs-2020/', 'poster_url': '/film/palm-springs-2020/image-150/', 'title': 'Palm Springs'}
# {'film_id': '430806', 'film_slug': 'im-thinking-of-ending-things', 'film_url': '/film/im-thinking-of-ending-things/', 'poster_url': '/film/im-thinking-of-ending-things/image-150/', 'title': "I'm Thinking of Ending Things"}
# {'film_id': '541425', 'film_slug': 'mank', 'film_url': '/film/mank/', 'poster_url': '/film/mank/image-150/', 'title': 'Mank'}
# {'film_id': '50752', 'film_slug': 'the-long-goodbye', 'film_url': '/film/the-long-goodbye/', 'poster_url': '/film/the-long-goodbye/image-150/', 'title': 'The Long Goodbye'}
# {'film_id': '45319', 'film_slug': 'the-mission', 'film_url': '/film/the-mission/', 'poster_url': '/film/the-mission/image-150/', 'title': 'The Mission'}
# {'film_id': '542449', 'film_slug': 'minari', 'film_url': '/film/minari/', 'poster_url': '/film/minari/image-150/', 'title': 'Minari'}
# {'film_id': '635253', 'film_slug': 'mangrove-2020', 'film_url': '/film/mangrove-2020/', 'poster_url': '/film/mangrove-2020/image-150/', 'title': 'Mangrove'}
# {'film_id': '470369', 'film_slug': 'kajillionaire', 'film_url': '/film/kajillionaire/', 'poster_url': '/film/kajillionaire/image-150/', 'title': 'Kajillionaire'}
# {'film_id': '503632', 'film_slug': 'on-the-rocks-2020', 'film_url': '/film/on-the-rocks-2020/', 'poster_url': '/film/on-the-rocks-2020/image-150/', 'title': 'On the Rocks'}
# {'film_id': '509662', 'film_slug': 'nomadland', 'film_url': '/film/nomadland/', 'poster_url': '/film/nomadland/image-150/', 'title': 'Nomadland'}
# {'film_id': '50780', 'film_slug': 'the-devils-advocate', 'film_url': '/film/the-devils-advocate/', 'poster_url': '/film/the-devils-advocate/image-150/', 'title': "The Devil's Advocate"}
# {'film_id': '130450', 'film_slug': 'a-field-in-england', 'film_url': '/film/a-field-in-england/', 'poster_url': '/film/a-field-in-england/image-150/', 'title': 'A Field in England'}
# {'film_id': '51529', 'film_slug': 'the-conversation', 'film_url': '/film/the-conversation/', 'poster_url': '/film/the-conversation/image-150/', 'title': 'The Conversation'}
# {'film_id': '11412', 'film_slug': 'june-17th-1994', 'film_url': '/film/june-17th-1994/', 'poster_url': '/film/june-17th-1994/image-150/', 'title': 'June 17th, 1994'}
# {'film_id': '51501', 'film_slug': 'a-fish-called-wanda', 'film_url': '/film/a-fish-called-wanda/', 'poster_url': '/film/a-fish-called-wanda/image-150/', 'title': 'A Fish Called Wanda'}
# {'film_id': '51228', 'film_slug': 'do-the-right-thing', 'film_url': '/film/do-the-right-thing/', 'poster_url': '/film/do-the-right-thing/image-150/', 'title': 'Do the Right Thing'}
# {'film_id': '30980', 'film_slug': 'affliction', 'film_url': '/film/affliction/', 'poster_url': '/film/affliction/image-150/', 'title': 'Affliction'}
# ...
# {'film_id': '46217', 'film_slug': 'eat-drink-man-woman', 'film_url': '/film/eat-drink-man-woman/', 'poster_url': '/film/eat-drink-man-woman/image-150/', 'title': 'Eat Drink Man Woman'}
# {'film_id': '27183', 'film_slug': 'the-graduate', 'film_url': '/film/the-graduate/', 'poster_url': '/film/the-graduate/image-150/', 'title': 'The Graduate'}
# {'film_id': '50956', 'film_slug': 'raging-bull', 'film_url': '/film/raging-bull/', 'poster_url': '/film/raging-bull/image-150/', 'title': 'Raging Bull'}
# {'film_id': '291610', 'film_slug': 'three-billboards-outside-ebbing-missouri', 'film_url': '/film/three-billboards-outside-ebbing-missouri/', 'poster_url': '/film/three-billboards-outside-ebbing-missouri/image-150/', 'title': 'Three Billboards Outside Ebbing, Missouri'}
# {'film_id': '450166', 'film_slug': 'her-smell', 'film_url': '/film/her-smell/', 'poster_url': '/film/her-smell/image-150/', 'title': 'Her Smell'}
# {'film_id': '404352', 'film_slug': 'the-souvenir', 'film_url': '/film/the-souvenir/', 'poster_url': '/film/the-souvenir/image-150/', 'title': 'The Souvenir'}
# {'film_id': '460830', 'film_slug': 'portrait-of-a-lady-on-fire', 'film_url': '/film/portrait-of-a-lady-on-fire/', 'poster_url': '/film/portrait-of-a-lady-on-fire/image-150/', 'title': 'Portrait of a Lady on Fire'}
# {'film_id': '575704', 'film_slug': 'john-mulaney-the-sack-lunch-bunch', 'film_url': '/film/john-mulaney-the-sack-lunch-bunch/', 'poster_url': '/film/john-mulaney-the-sack-lunch-bunch/image-150/', 'title': 'John Mulaney & The Sack Lunch Bunch'}
# {'film_id': '435450', 'film_slug': 'booksmart', 'film_url': '/film/booksmart/', 'poster_url': '/film/booksmart/image-150/', 'title': 'Booksmart'}
# {'film_id': '293066', 'film_slug': 'suspiria-2018', 'film_url': '/film/suspiria-2018/', 'poster_url': '/film/suspiria-2018/image-150/', 'title': 'Suspiria'}
# {'film_id': '25454', 'film_slug': 'somewhere', 'film_url': '/film/somewhere/', 'poster_url': '/film/somewhere/image-150/', 'title': 'Somewhere'}
# {'film_id': '51630', 'film_slug': 'pi', 'film_url': '/film/pi/', 'poster_url': '/film/pi/image-150/', 'title': 'Pi'}
# {'film_id': '51140', 'film_slug': 'babel-2006', 'film_url': '/film/babel-2006/', 'poster_url': '/film/babel-2006/image-150/', 'title': 'Babel'}
# {'film_id': '433863', 'film_slug': 'the-lighthouse-2019', 'film_url': '/film/the-lighthouse-2019/', 'poster_url': '/film/the-lighthouse-2019/image-150/', 'title': 'The Lighthouse'}
# {'film_id': '49039', 'film_slug': 'synecdoche-new-york', 'film_url': '/film/synecdoche-new-york/', 'poster_url': '/film/synecdoche-new-york/image-150/', 'title': 'Synecdoche, New York'}
# {'film_id': '51339', 'film_slug': 'airplane', 'film_url': '/film/airplane/', 'poster_url': '/film/airplane/image-150/', 'title': 'Airplane!'}
# {'film_id': '51751', 'film_slug': 'broken-flowers', 'film_url': '/film/broken-flowers/', 'poster_url': '/film/broken-flowers/image-150/', 'title': 'Broken Flowers'}
# {'film_id': '464735', 'film_slug': 'the-dead-dont-die-2019', 'film_url': '/film/the-dead-dont-die-2019/', 'poster_url': '/film/the-dead-dont-die-2019/image-150/', 'title': "The Dead Don't Die"}
# {'film_id': '51816', 'film_slug': 'the-godfather-part-ii', 'film_url': '/film/the-godfather-part-ii/', 'poster_url': '/film/the-godfather-part-ii/image-150/', 'title': 'The Godfather Part II'}
# {'film_id': '51818', 'film_slug': 'the-godfather', 'film_url': '/film/the-godfather/', 'poster_url': '/film/the-godfather/image-150/', 'title': 'The Godfather'}
# {'film_id': '335294', 'film_slug': 'sicario-day-of-the-soldado', 'film_url': '/film/sicario-day-of-the-soldado/', 'poster_url': '/film/sicario-day-of-the-soldado/image-150/', 'title': 'Sicario: Day of the Soldado'}
# {'film_id': '426131', 'film_slug': 'birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn', 'film_url': '/film/birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn/', 'poster_url': '/film/birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn/image-150/', 'title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)'}
# {'film_id': '431540', 'film_slug': 'synonyms', 'film_url': '/film/synonyms/', 'poster_url': '/film/synonyms/image-150/', 'title': 'Synonyms'}
# {'film_id': '36192', 'film_slug': 'come-and-see', 'film_url': '/film/come-and-see/', 'poster_url': '/film/come-and-see/image-150/', 'title': 'Come and See'}
# {'film_id': '44900', 'film_slug': 'suspiria', 'film_url': '/film/suspiria/', 'poster_url': '/film/suspiria/image-150/', 'title': 'Suspiria'}
# {'film_id': '69998', 'film_slug': 'cloud-atlas', 'film_url': '/film/cloud-atlas/', 'poster_url': '/film/cloud-atlas/image-150/', 'title': 'Cloud Atlas'}
# {'film_id': '216086', 'film_slug': 'the-handmaiden', 'film_url': '/film/the-handmaiden/', 'poster_url': '/film/the-handmaiden/image-150/', 'title': 'The Handmaiden'}
# {'film_id': '51994', 'film_slug': 'heat-1995', 'film_url': '/film/heat-1995/', 'poster_url': '/film/heat-1995/image-150/', 'title': 'Heat'}
# {'film_id': '259011', 'film_slug': 'band-of-brothers', 'film_url': '/film/band-of-brothers/', 'poster_url': '/film/band-of-brothers/image-150/', 'title': 'Band of Brothers'}
# {'film_id': '51320', 'film_slug': 'm', 'film_url': '/film/m/', 'poster_url': '/film/m/image-150/', 'title': 'M'}
# {'film_id': '71927', 'film_slug': 'boyhood', 'film_url': '/film/boyhood/', 'poster_url': '/film/boyhood/image-150/', 'title': 'Boyhood'}
# {'film_id': '102444', 'film_slug': 'before-midnight', 'film_url': '/film/before-midnight/', 'poster_url': '/film/before-midnight/image-150/', 'title': 'Before Midnight'}
# {'film_id': '51970', 'film_slug': 'before-sunset', 'film_url': '/film/before-sunset/', 'poster_url': '/film/before-sunset/image-150/', 'title': 'Before Sunset'}
# {'film_id': '49391', 'film_slug': 'atonement', 'film_url': '/film/atonement/', 'poster_url': '/film/atonement/image-150/', 'title': 'Atonement'}
# {'film_id': '43203', 'film_slug': 'ninja-scroll', 'film_url': '/film/ninja-scroll/', 'poster_url': '/film/ninja-scroll/image-150/', 'title': 'Ninja Scroll'}
# {'film_id': '67195', 'film_slug': 'jiro-dreams-of-sushi', 'film_url': '/film/jiro-dreams-of-sushi/', 'poster_url': '/film/jiro-dreams-of-sushi/image-150/', 'title': 'Jiro Dreams of Sushi'}
# {'film_id': '51469', 'film_slug': 'paris-texas', 'film_url': '/film/paris-texas/', 'poster_url': '/film/paris-texas/image-150/', 'title': 'Paris, Texas'}
# {'film_id': '132034', 'film_slug': 'enemy', 'film_url': '/film/enemy/', 'poster_url': '/film/enemy/image-150/', 'title': 'Enemy'}
# {'film_id': '51972', 'film_slug': 'blade-runner', 'film_url': '/film/blade-runner/', 'poster_url': '/film/blade-runner/image-150/', 'title': 'Blade Runner'}
# {'film_id': '139795', 'film_slug': 'birdman-or-the-unexpected-virtue-of-ignorance', 'film_url': '/film/birdman-or-the-unexpected-virtue-of-ignorance/', 'poster_url': '/film/birdman-or-the-unexpected-virtue-of-ignorance/image-150/', 'title': 'Birdman or (The Unexpected Virtue of Ignorance)'}
# {'film_id': '467061', 'film_slug': 'the-ballad-of-buster-scruggs', 'film_url': '/film/the-ballad-of-buster-scruggs/', 'poster_url': '/film/the-ballad-of-buster-scruggs/image-150/', 'title': 'The Ballad of Buster Scruggs'}
# {'film_id': '193748', 'film_slug': 'hail-caesar-2016', 'film_url': '/film/hail-caesar-2016/', 'poster_url': '/film/hail-caesar-2016/image-150/', 'title': 'Hail, Caesar!'}
# {'film_id': '44466', 'film_slug': 'a-serious-man', 'film_url': '/film/a-serious-man/', 'poster_url': '/film/a-serious-man/image-150/', 'title': 'A Serious Man'}
# {'film_id': '48813', 'film_slug': 'the-ladykillers-2004-6', 'film_url': '/film/the-ladykillers-2004-6/', 'poster_url': '/film/the-ladykillers-2004-6/image-150/', 'title': 'The Ladykillers'}
# {'film_id': '45020', 'film_slug': 'intolerable-cruelty', 'film_url': '/film/intolerable-cruelty/', 'poster_url': '/film/intolerable-cruelty/image-150/', 'title': 'Intolerable Cruelty'}
# {'film_id': '45906', 'film_slug': 'the-man-who-wasnt-there-2001', 'film_url': '/film/the-man-who-wasnt-there-2001/', 'poster_url': '/film/the-man-who-wasnt-there-2001/image-150/', 'title': "The Man Who Wasn't There"}
# {'film_id': '44873', 'film_slug': 'the-hudsucker-proxy', 'film_url': '/film/the-hudsucker-proxy/', 'poster_url': '/film/the-hudsucker-proxy/image-150/', 'title': 'The Hudsucker Proxy'}
# {'film_id': '51706', 'film_slug': 'millers-crossing', 'film_url': '/film/millers-crossing/', 'poster_url': '/film/millers-crossing/image-150/', 'title': "Miller's Crossing"}
# {'film_id': '45366', 'film_slug': 'blood-simple', 'film_url': '/film/blood-simple/', 'poster_url': '/film/blood-simple/image-150/', 'title': 'Blood Simple'}
# {'film_id': '49007', 'film_slug': 'boogie-nights', 'film_url': '/film/boogie-nights/', 'poster_url': '/film/boogie-nights/image-150/', 'title': 'Boogie Nights'}
# {'film_id': '48044', 'film_slug': 'there-will-be-blood', 'film_url': '/film/there-will-be-blood/', 'poster_url': '/film/there-will-be-blood/image-150/', 'title': 'There Will Be Blood'}
# {'film_id': '22915', 'film_slug': 'down-terrace', 'film_url': '/film/down-terrace/', 'poster_url': '/film/down-terrace/image-150/', 'title': 'Down Terrace'}
# {'film_id': '40276', 'film_slug': 'bronson', 'film_url': '/film/bronson/', 'poster_url': '/film/bronson/image-150/', 'title': 'Bronson'}
# {'film_id': '42788', 'film_slug': 'london-to-brighton', 'film_url': '/film/london-to-brighton/', 'poster_url': '/film/london-to-brighton/image-150/', 'title': 'London to Brighton'}
# {'film_id': '49114', 'film_slug': 'layer-cake', 'film_url': '/film/layer-cake/', 'poster_url': '/film/layer-cake/image-150/', 'title': 'Layer Cake'}
# {'film_id': '46272', 'film_slug': 'gangster-no-1', 'film_url': '/film/gangster-no-1/', 'poster_url': '/film/gangster-no-1/image-150/', 'title': 'Gangster No. 1'}
# {'film_id': '51618', 'film_slug': 'being-john-malkovich', 'film_url': '/film/being-john-malkovich/', 'poster_url': '/film/being-john-malkovich/image-150/', 'title': 'Being John Malkovich'}
# {'film_id': '39358', 'film_slug': 'pandorum', 'film_url': '/film/pandorum/', 'poster_url': '/film/pandorum/image-150/', 'title': 'Pandorum'}
# {'film_id': '51171', 'film_slug': 'mulholland-drive', 'film_url': '/film/mulholland-drive/', 'poster_url': '/film/mulholland-drive/image-150/', 'title': 'Mulholland Drive'}
# {'film_id': '45409', 'film_slug': 'shutter-island', 'film_url': '/film/shutter-island/', 'poster_url': '/film/shutter-island/image-150/', 'title': 'Shutter Island'}
# {'film_id': '51910', 'film_slug': 'donnie-darko', 'film_url': '/film/donnie-darko/', 'poster_url': '/film/donnie-darko/image-150/', 'title': 'Donnie Darko'}
# {'film_id': '51921', 'film_slug': 'spirited-away', 'film_url': '/film/spirited-away/', 'poster_url': '/film/spirited-away/image-150/', 'title': 'Spirited Away'}
# {'film_id': '285509', 'film_slug': 'coco-2017', 'film_url': '/film/coco-2017/', 'poster_url': '/film/coco-2017/image-150/', 'title': 'Coco'}
# {'film_id': '2703', 'film_slug': 'american-beauty', 'film_url': '/film/american-beauty/', 'poster_url': '/film/american-beauty/image-150/', 'title': 'American Beauty'}
# {'film_id': '80198', 'film_slug': 'under-the-skin-2013', 'film_url': '/film/under-the-skin-2013/', 'poster_url': '/film/under-the-skin-2013/image-150/', 'title': 'Under the Skin'}
# {'film_id': '370918', 'film_slug': 'birds-of-passage-2018', 'film_url': '/film/birds-of-passage-2018/', 'poster_url': '/film/birds-of-passage-2018/image-150/', 'title': 'Birds of Passage'}
# {'film_id': '459564', 'film_slug': 'midsommar', 'film_url': '/film/midsommar/', 'poster_url': '/film/midsommar/image-150/', 'title': 'Midsommar'}
# {'film_id': '2694', 'film_slug': 'kill-bill-vol-1', 'film_url': '/film/kill-bill-vol-1/', 'poster_url': '/film/kill-bill-vol-1/image-150/', 'title': 'Kill Bill: Vol. 1'}
# {'film_id': '51987', 'film_slug': '2001-a-space-odyssey', 'film_url': '/film/2001-a-space-odyssey/', 'poster_url': '/film/2001-a-space-odyssey/image-150/', 'title': '2001: A Space Odyssey'}
# {'film_id': '424348', 'film_slug': 'hereditary', 'film_url': '/film/hereditary/', 'poster_url': '/film/hereditary/image-150/', 'title': 'Hereditary'}
# {'film_id': '333029', 'film_slug': 'call-me-by-your-name', 'film_url': '/film/call-me-by-your-name/', 'poster_url': '/film/call-me-by-your-name/image-150/', 'title': 'Call Me by Your Name'}
# {'film_id': '312205', 'film_slug': 'moonlight-2016', 'film_url': '/film/moonlight-2016/', 'poster_url': '/film/moonlight-2016/image-150/', 'title': 'Moonlight'}
# {'film_id': '171384', 'film_slug': 'whiplash-2014', 'film_url': '/film/whiplash-2014/', 'poster_url': '/film/whiplash-2014/image-150/', 'title': 'Whiplash'}
# {'film_id': '114564', 'film_slug': 'her', 'film_url': '/film/her/', 'poster_url': '/film/her/image-150/', 'title': 'Her'}
# {'film_id': '326279', 'film_slug': 'lady-bird', 'film_url': '/film/lady-bird/', 'poster_url': '/film/lady-bird/image-150/', 'title': 'Lady Bird'}
# {'film_id': '240344', 'film_slug': 'la-la-land', 'film_url': '/film/la-la-land/', 'poster_url': '/film/la-la-land/image-150/', 'title': 'La La Land'}
# {'film_id': '51935', 'film_slug': 'the-big-lebowski', 'film_url': '/film/the-big-lebowski/', 'poster_url': '/film/the-big-lebowski/image-150/', 'title': 'The Big Lebowski'}
# {'film_id': '73367', 'film_slug': 'inside-llewyn-davis', 'film_url': '/film/inside-llewyn-davis/', 'poster_url': '/film/inside-llewyn-davis/image-150/', 'title': 'Inside Llewyn Davis'}
# {'film_id': '51781', 'film_slug': 'fargo', 'film_url': '/film/fargo/', 'poster_url': '/film/fargo/image-150/', 'title': 'Fargo'}
# {'film_id': '51939', 'film_slug': 'scarface-1983', 'film_url': '/film/scarface-1983/', 'poster_url': '/film/scarface-1983/image-150/', 'title': 'Scarface'}
# {'film_id': '166181', 'film_slug': 'marshland', 'film_url': '/film/marshland/', 'poster_url': '/film/marshland/image-150/', 'title': 'Marshland'}
#     film_id                      film_slug  \
# 0     25650                       sorcerer
# 1     51261         all-the-presidents-men
# 2     45652  the-last-temptation-of-christ
# 3    591053                     past-lives
# 4    438692          the-boy-and-the-heron
# ..      ...                            ...
# 231   51935               the-big-lebowski
# 232   73367            inside-llewyn-davis
# 233   51781                          fargo
# 234   51939                  scarface-1983
# 235  166181                      marshland
#
#                                  film_url  \
# 0                         /film/sorcerer/
# 1           /film/all-the-presidents-men/
# 2    /film/the-last-temptation-of-christ/
# 3                       /film/past-lives/
# 4            /film/the-boy-and-the-heron/
# ..                                    ...
# 231               /film/the-big-lebowski/
# 232            /film/inside-llewyn-davis/
# 233                          /film/fargo/
# 234                  /film/scarface-1983/
# 235                      /film/marshland/
#
#                                          poster_url  \
# 0                         /film/sorcerer/image-150/
# 1           /film/all-the-presidents-men/image-150/
# 2    /film/the-last-temptation-of-christ/image-150/
# 3                       /film/past-lives/image-150/
# 4            /film/the-boy-and-the-heron/image-150/
# ..                                              ...
# 231               /film/the-big-lebowski/image-150/
# 232            /film/inside-llewyn-davis/image-150/
# 233                          /film/fargo/image-150/
# 234                  /film/scarface-1983/image-150/
# 235                      /film/marshland/image-150/
#
#                              title
# 0                         Sorcerer
# 1          All the President's Men
# 2    The Last Temptation of Christ
# 3                       Past Lives
# 4            The Boy and the Heron
# ..                             ...
# 231               The Big Lebowski
# 232            Inside Llewyn Davis
# 233                          Fargo
# 234                       Scarface
# 235                      Marshland
#
# [236 rows x 5 columns]
